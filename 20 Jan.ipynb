# %% [markdown]
# # Introduction to Python

# %% [markdown]
# ## Python

# %% [markdown]
# Python is a high-level, interpreted, and general-purpose programming language known for its simple syntax and readability.

# %% [markdown]
# ##  why it is different from other programming languages?

# %% [markdown]
# Python and Java are both popular programming languages, but they differ in design philosophy and usage.
#
# 1. Syntax
#
# Python has simple, readable syntax and uses indentation to define code blocks.
#
# Java has a more verbose syntax and uses braces {} and semicolons ;.

# %% [markdown]
# syntax for java:
#
# class HelloWorld {
#
#     public static void main(String[] args) {
#         System.out.println("Hello, World!");
#
#     }
# }

# %%
# Syntax for Java Programming 
a=4
b=10
print(b-a)
# Out:
# 6

# %%
2. Typing

Python is dynamically typed, meaning variable types are decided at runtime.

Java is statically typed, meaning variable types must be declared explicitly.
