# %% [markdown]
# ## DAY 1

# %% [markdown]
# program to print nam, age and city

# %%
name= " Ritika"
age= 18
city= " Dehradun"

print("Name", name)
print("Age", age)
print("City", city)
# Out:
# Name  Ritika
# Age 18
# City  Dehradun

# %% [markdown]
# Program to declare variables and identify their type

# %%
num = 17
price = 20.22
language="en"
is_fun= True

print(num)
print(type(num))
print(type(price))
print(type(language))
print(type(is_fun))
# Out:
# 17
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# Program to add string with integer value

# %%
data = 100
print(data)
print(type(data))

str1="100"
print(data + int(str1))
# Out:
# 100
# <class 'int'>
# 200

# %% [markdown]
# Program to add two numbers

# %%
num1=100
num2= 150
print("sum of two numbers is: ", num1+num2)
